# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.basicConfig()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !mkdir -p /drive

#umount /drive
# !mount --bind /content/drive/My\ Drive /drive
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append("/content/drive/MyDrive/패스트캠퍼스강의/실습자료/ch1")

# %%
import argparse
import logging
import random
import time
import importlib

import torch
import torch.backends.cudnn as cudnn
from torch import optim
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence


from tqdm import tqdm

from utils.batches import batches, data_from_batch
from utils.embeddings import create_embedding_maps
from utils.masked_cross_entropy import masked_cross_entropy
from utils.tokens import Tokens

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
batch_size = 50
hidden_size = 500
input_size = 500
different_vocab = True
learning_rate = 0.0001
eval_every = 50
eval_batch_size = 10 
n_layers = 2 
n_epochs = 10 
dropout = 0.1 
score_function = "general"
teacher_forcing_ratio = 1
decoder_learning_ratio = 5.
clip_norm = 5.0
rnn_cell = "GRU"
use_cuda = True
use_batch_attention = True

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, input_size, n_layers, dropout, word_embedding_matrix, rnn_cell, use_cuda):
        super().__init__()
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.n_layers = n_layers
        self.dropout = dropout
        self.embedding = word_embedding_matrix
        self.use_cuda = use_cuda

        if rnn_cell == "GRU":
            self.rnn = nn.GRU(input_size, hidden_size, n_layers, dropout=dropout, bidirectional=True)

    def forward(self, input_seqs, hidden, input_lengths):
        """
        input_seqs : (Max input length, batch_size)
        input_lengths: (batch_size)
        """

        # Max input length, batch size, hidden_size
        embedded = self.embedding(input_seqs)
        packed = pack_padded_sequence(embedded, input_lengths)
        outputs, hidden = self.rnn(packed, hidden)
        outputs, output_lengths = pad_packed_sequence(outputs)

        # Max input length, batch_size, hidden_size, we add the backward and forward
        # hidden states together
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, :, self.hidden_size:]

        # Get the forwards and backwards hidden states
        hidden_layers = []
        for i in range(self.n_layers):
            hidden_layers.append((hidden[i * 2, :, :] + hidden[(i * 2) + 1, :, :]).unsqueeze(0))
        return outputs, torch.cat(hidden_layers, 0)

    def init_hidden(self, batch_size):
        hidden = Variable(torch.zeros(self.n_layers * 2, batch_size, self.hidden_size))
        if self.use_cuda: hidden = hidden.cuda()
        return hidden

class Attn(nn.Module):
    def __init__(self, method, hidden_size, use_cuda=False):
        super().__init__()
        self.method = method
        self.hidden_size = hidden_size
        self.use_cuda = use_cuda

        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(1, hidden_size))

    def forward(self, hidden, encoder_outputs):
        """
        hidden : 1, batch_size, hidden_size
        encoder_outputs : max input length, batch_size, hidden_size
        """
        # max_len = encoder_outputs.size(0)
        # this_batch_size = encoder_outputs.size(1)

        attn_energies = torch.bmm(self.attn(hidden).transpose(1, 0), encoder_outputs.permute(1, 2, 0))

        # Batch size, 1, max input length
        return F.softmax(attn_energies)

    def score(self, hidden, encoder_output):

        if self.method == 'general':
            energy = self.attn(encoder_output).view(-1)
            energy = hidden.view(-1).dot(energy)
            return energy



class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, score_function, hidden_size, input_size, output_size,
                 n_layers, dropout , word_embedding_matrix, use_cuda):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.score_function = score_function
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout
        self.use_cuda = use_cuda

        # Define layers
        self.embedding = word_embedding_matrix
        self.gru = nn.GRU(self.input_size, self.hidden_size, n_layers, dropout=self.dropout)
        self.concat = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

        # Choose attention models
        if score_function != 'none':
            self.attn = Attn(score_function, hidden_size, use_cuda=use_cuda)

    def forward(self, input_seq, last_hidden, encoder_outputs):
        """
        input_seq : batch_size
        hidden : hidden_size, batch_size
        encoder_outputs : max input length, batch_size, hidden_size
        """
        # Note: we run this one step at a time

        # logging.debug(f"input_seq:\n{input_seq}")
        # logging.debug(f"last_hidden:\n{last_hidden}")
        # logging.debug(f"encoder_outputs:\n{encoder_outputs}")

        batch_size = input_seq.size(0)

        # (batch size, hidden_size)
        embedded = self.embedding(input_seq)

        # (1, batch size, input_size) add another dimension so that it works with
        # the GRU
        embedded = embedded.view(1, batch_size, self.input_size)  # S=1 x B x N

        logging.debug(f"embedded:\n{embedded}")
        # Get current hidden state from input word and last hidden state
        rnn_output, hidden = self.gru(embedded, last_hidden)
        logging.debug(f"rnn_output:\n{rnn_output}")
        logging.debug(f"hidden:\n{hidden}")


        # Calculate attention from current RNN state and all encoder outputs;
        # apply to encoder outputs to get weighted average

        # batch size, max input length
        attn_weights = self.attn(rnn_output, encoder_outputs)
        logging.debug(f"attn_weights:\n{attn_weights}")

        # (batch_size, 1, max input length) @ batch_size, max input length, hidden size
        # note that we use this convention here to take advantage of the bmm function
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))  # B x S=1 x N

        # Attentional vector using the RNN hidden state and context vector
        # concatenated together (Luong eq. 5)
        rnn_output = rnn_output.squeeze(0)  # S=1 x B x N -> B x N
        context = context.squeeze(1)  # B x S=1 x N -> B x N
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = F.tanh(self.concat(concat_input))

        # Finally predict next token (Luong eq. 6, without fftmax)
        output = self.out(concat_output)

        # Return final output, hidden state, and attention weights (for visualization)
        return output, hidden, attn_weights

# %%
def run_train(n_epochs,
              batch_size,
              eval_batch_size,
              eval_every,
              train,
              val,
              encoder_embedding_map,
              decoder_embedding_map,
              encoder,
              decoder,
              encoder_optimizer,
              decoder_optimizer,
              clip_norm,
              teacher_forcing_ratio,
              use_cuda,
              ):
    for i in range(n_epochs):
        logging.info(f"EPOCH: {i+1}")
        for j, batch in enumerate(tqdm(batches(train,
                                               encoder_embedding_map,
                                               decoder_embedding_map,
                                               use_cuda=use_cuda,
                                               batch_size=batch_size))):
            encoder.train()
            decoder.train()
            encoder_optimizer.zero_grad()
            decoder_optimizer.zero_grad()

            source_var, source_lengths, target_var, target_lengths = data_from_batch(batch)

            current_batch_size = len(target_lengths)

            # encoder_outputs: max input length, batch size, hidden size
            # encoder_hidden: num_layers, batch size, hidden size
            logging.debug("Encoding")
            tic = time.time()
            encoder_outputs, encoder_hidden = encoder(source_var,
                                                      encoder.init_hidden(current_batch_size),
                                                      source_lengths)
            toc = time.time()
            logging.debug(f"Seconds take to encode: {round(toc-tic,2)}")
            decoder_input = Variable(torch.LongTensor([Tokens.SOS_token] * current_batch_size))
            decoder_hidden = encoder_hidden
            if use_cuda:
                decoder_input = decoder_input.cuda()
                decoder_hidden = decoder_hidden.cuda()

            logging.debug("Decoding")
            tic = time.time()

            max_target_length = max(target_lengths)
            all_decoder_outputs = Variable(torch.zeros(max_target_length, current_batch_size, decoder.output_size))




            if use_cuda:
                all_decoder_outputs = all_decoder_outputs.cuda()

            use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

            if use_teacher_forcing:
                logging.debug("Using teacher forcing")
                for t in range(max_target_length):
                    decoder_output, decoder_hidden, att = decoder(decoder_input,
                                                                decoder_hidden,
                                                                encoder_outputs)
                    all_decoder_outputs[t] = decoder_output


                    decoder_input = target_var[t]
            else:
                ## TODO: how do I do non-teacher forcing for batch inputs?
                logging.debug("Not using teacher forcing")
                for t in range(max_target_length):
                    decoder_output, decoder_hidden, _ = decoder(decoder_input,
                                                                decoder_hidden,
                                                                encoder_outputs)
                    all_decoder_outputs[t] = decoder_output
                    _, top_i = decoder_output.data.topk(1)
                    decoder_input = Variable(top_i).squeeze(1)

            toc = time.time()
            loss = masked_cross_entropy(all_decoder_outputs.transpose(0, 1).contiguous(),
                                        target_var.transpose(0, 1).contiguous(),
                                        target_lengths,
                                        use_cuda=use_cuda)
            logging.debug(f"Time taken for 1 decode step: {round(toc-tic, 2)}")
            logging.debug("Backpropagating")

            tic = time.time()
            loss.backward()
            toc = time.time()
            logging.debug(f"Seconds taken for backpropagation: {round(toc-tic, 2)}")

            # Clip gradients
            logging.debug("Clipping Gradients")
            _ = torch.nn.utils.clip_grad_norm(encoder.parameters(), clip_norm)
            _ = torch.nn.utils.clip_grad_norm(decoder.parameters(), clip_norm)

            logging.debug("Updating Weights")
            encoder_optimizer.step()
            decoder_optimizer.step()

            if j % eval_every == 0:
                run_eval(encoder_embedding_map,
                         decoder_embedding_map,
                         encoder,
                         decoder,
                         val,
                         eval_batch_size,
                         use_cuda=use_cuda)

                run_eval(encoder_embedding_map,
                         decoder_embedding_map,
                         encoder,
                         decoder,
                         train,
                         batch_size,
                         use_cuda=use_cuda)

            logging.info(f"LOSS: {loss.data}")


def run_eval(encoder_embedding_map,
             decoder_embedding_map,
             encoder,
             decoder,
             val,
             batch_size,
             use_cuda=False):

    batch = next(batches(val,
                 encoder_embedding_map,
                 decoder_embedding_map,
                 bucket=False,
                 batch_size=batch_size,
                 use_cuda=use_cuda))

    # Disable to avoid dropout
    encoder.eval()
    decoder.eval()

    source_var, source_lengths, target_var, target_lengths = data_from_batch(batch)
    
    current_batch_size = len(target_lengths)

    encoder_outputs, encoder_hidden = encoder(source_var,
                                              encoder.init_hidden(current_batch_size),
                                              source_lengths)

    # (1, eval_batch_size)
    decoder_inputs = Variable(torch.LongTensor([Tokens.SOS_token] * current_batch_size))
    decoder_hidden = encoder_hidden
    max_target_length = max(target_lengths)
    all_decoder_outputs = Variable(torch.zeros(max_target_length, current_batch_size, decoder.output_size))

    if use_cuda:
        decoder_inputs = decoder_inputs.cuda()
        all_decoder_outputs = all_decoder_outputs.cuda()

    # decoder_attentions = torch.zeros(eval_batch_size, max_target_length, max_target_length)
    decoder_attentions = torch.zeros(max_target_length, max_target_length)

    logging.info("Decoding")

    for t in tqdm(range(max_target_length)):
        decoder_output, decoder_hidden, attn_weights = decoder(decoder_inputs,
                                                               decoder_hidden,
                                                               encoder_outputs)
        decoder_attentions[t] = attn_weights[0].detach() # (max_leng)

        # num_time_step (will be 1), batch_size, output_vocab_size
        all_decoder_outputs[t] = decoder_output

        # num_time_step (will be 1), batch_size, 1
        _, top_i = decoder_output.data.topk(1)
        decoder_inputs = Variable(top_i).squeeze(1)
        # colorbar로 그림 설정
    print(attn_weights.shape)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(decoder_attentions.detach().to("cpu").numpy(), cmap='bone')
    fig.colorbar(cax)

    format_eval_output(encoder_embedding_map,
                       decoder_embedding_map,
                       source_var,
                       target_var,
                       all_decoder_outputs)


def format_eval_output(encoder_embedding_map,
                       decoder_embedding_map,
                       inp,
                       target,
                       all_decoder_outputs):
    inp = inp.cpu()
    target = target.cpu()
    _, batch_top_i = all_decoder_outputs.topk(1)
    batch_top_i = batch_top_i.cpu().squeeze(-1).transpose(1, 0).data.numpy()

    input_sentences = []
    target_sentences = []
    decoded_sentences = []

    for var in inp.transpose(1, 0).data.numpy():
        input_sentences.append(encoder_embedding_map.get_sentence_from_indexes(var))
    for var in target.transpose(1, 0).data.numpy():
        target_sentences.append(decoder_embedding_map.get_sentence_from_indexes(var))
    for indexes in batch_top_i:
        sentence = decoder_embedding_map.get_sentence_from_indexes(indexes)
        trunc_sentence = []
        for word in sentence:
            if word != "<EOS>":
                trunc_sentence.append(word)
            else:
                break
        decoded_sentences.append(trunc_sentence)

    for source, target, decode in zip(input_sentences, target_sentences, decoded_sentences):
        logging.info(f"\nSource:{' '.join(source)}\nTarget:{' '.join(target)}\nDecode:{' '.join(decode)}")

# %%
def load_data(dataset_module, train_dir, debug_restrict_data):
    dataset_module_path = f"utils.load_and_preprocessing.{dataset_module}"
    dataset_module = importlib.import_module(dataset_module_path)
    train, val = dataset_module.load_data(train_dir, debug_restrict_data)
    return train, val
train, val = load_data("translation", "/content/drive/MyDrive/패스트캠퍼스강의/실습자료/ch1/data/translation", None)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# 100%|██████████| 10835/10835 [00:00<00:00, 1491231.63it/s]
# 100%|██████████| 10/10 [00:00<00:00, 5548.02it/s]

# %%
val
# Out:
#                                    source  \
# 0         je vais vous conter un secret .
# 1                     elles sont russes .
# 2                   il est photogenique .
# 3                 on est dans les clous .
# 4                       c est un auteur .
# 5              vous etes trop confiante .
# 6  je suis en train de changer de poste .
# 7  elle plante des roses dans le jardin .
# 8               vous etes tres elegante .
# 9                  nous sommes bourrees .
#
#                                  target
# 0      i m going to tell you a secret .
# 1                    they are russian .
# 2                    he is photogenic .
# 3                   we re on schedule .
# 4                      he s an author .
# 5                 you re too trusting .
# 6                    i m between jobs .
# 7  she s in the garden planting roses .
# 8                 you re very stylish .
# 9                       we re sloshed .

# %%
logging.info("Creating embedding maps")
encoder_embedding_map, \
decoder_embedding_map, \
encoder_embedding_matrix, \
decoder_embedding_matrix = create_embedding_maps(train, val, input_size, different_vocab)
# Out:
# INFO:root:Creating embedding maps
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 10835/10835 [00:00<00:00, 149326.51it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 69098.91it/s]
# 100%|██████████| 2/2 [00:00<00:00, 17.04it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 10835/10835 [00:00<00:00, 161918.29it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 75166.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 16.62it/s]

# %%
encoder = EncoderRNN(hidden_size,
                          input_size,
                          n_layers,
                          dropout,
                          encoder_embedding_matrix,
                          rnn_cell,
                          use_cuda)

decoder = LuongAttnDecoderRNN(score_function,
                            hidden_size,
                            input_size,
                            decoder_embedding_map.n_words,
                            n_layers,
                            dropout,
                            decoder_embedding_matrix,
                            use_cuda)

# %%
encoder
# Out:
# EncoderRNN(
#   (embedding): Embedding(4490, 500)
#   (rnn): GRU(500, 500, num_layers=2, dropout=0.1, bidirectional=True)
# )

# %%
decoder
# Out:
# LuongAttnDecoderRNN(
#   (embedding): Embedding(2927, 500)
#   (gru): GRU(500, 500, num_layers=2, dropout=0.1)
#   (concat): Linear(in_features=1000, out_features=500, bias=True)
#   (out): Linear(in_features=500, out_features=2927, bias=True)
#   (attn): Attn(
#     (attn): Linear(in_features=500, out_features=500, bias=True)
#   )
# )

# %%
# %matplotlib inline
if use_cuda:
    encoder = encoder.cuda()
    decoder = decoder.cuda()

encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

logging.info("Starting training")

run_train(n_epochs,
          batch_size,
          eval_batch_size,
          eval_every,
          train,
          val,
          encoder_embedding_map,
          decoder_embedding_map,
          encoder,
          decoder,
          encoder_optimizer,
          decoder_optimizer,
          clip_norm,
          teacher_forcing_ratio,
          use_cuda,
          )
# Out:
# INFO:root:Starting training
# INFO:root:EPOCH: 1
# 0it [00:00, ?it/s]<ipython-input-7-a15f1f01e15d>:65: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(attn_energies)
# <ipython-input-27-e24957fedee2>:98: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   _ = torch.nn.utils.clip_grad_norm(encoder.parameters(), clip_norm)
# <ipython-input-27-e24957fedee2>:99: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   _ = torch.nn.utils.clip_grad_norm(decoder.parameters(), clip_norm)
# INFO:root:Decoding
#
# 100%|██████████| 10/10 [00:00<00:00, 113.85it/s]
# INFO:root:
# Source:je suis en train de changer de poste . <EOS>
# Target:i m between jobs . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m from england .
# INFO:root:
# Source:elle plante des roses dans le jardin . <EOS> <PAD>
# Target:she s in the garden planting roses . <EOS> <PAD>
# Decode:she is fond of making a host of problems .
# INFO:root:
# Source:je vais vous conter un secret . <EOS> <PAD> <PAD>
# Target:i m going to tell you a secret . <EOS>
# Decode:i m going to be a new car .
# INFO:root:
# Source:on est dans les clous . <EOS> <PAD> <PAD> <PAD>
# Target:we re on schedule . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re in trouble .
# INFO:root:
# Source:vous etes tres elegante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very stylish . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very timid .
# INFO:root:
# Source:c est un auteur . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s an author . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he s a gentleman .
# INFO:root:
# Source:vous etes trop confiante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re too trusting . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re too tense .
# INFO:root:
# Source:il est photogenique . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he is photogenic . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:he s a
# INFO:root:
# Source:nous sommes bourrees . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re sloshed . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re happy .
# INFO:root:
# Source:elles sont russes . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:they are russian . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:they re coming .
# INFO:root:Decoding
# torch.Size([10, 1, 10])
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 75.60it/s]
# INFO:root:
# Source:je ne suis pas la pour me battre . <EOS>
# Target:i m not here to fight . <EOS> <PAD> <PAD>
# Decode:i m not your friend .
# INFO:root:
# Source:je suis heureuse que tu l aies apprecie . <EOS>
# Target:i m glad you liked it . <EOS> <PAD> <PAD>
# Decode:i m glad you re here .
# INFO:root:
# Source:tu restes avec tom n est ce pas ? <EOS>
# Target:you re staying with tom right ? <EOS> <PAD> <PAD>
# Decode:you re new here aren t you ?
# INFO:root:
# Source:il est en train de lire un roman . <EOS>
# Target:he s reading a novel right now . <EOS> <PAD>
# Decode:he is a little bit tired .
# INFO:root:
# Source:il n est pas apte a etre enseignant . <EOS>
# Target:he is unfit to be a teacher . <EOS> <PAD>
# Decode:he is not a doctor to the result .
# INFO:root:
# Source:je te le demande en tant qu ami . <EOS>
# Target:i m asking you as a friend . <EOS> <PAD>
# Decode:i m glad you re all happy .
# INFO:root:
# Source:je suis ravi que vous ayez pu venir . <EOS>
# Target:i m glad you could make it . <EOS> <PAD>
# Decode:i m glad you re here .
# INFO:root:
# Source:je ne vous donnerai pas davantage d argent . <EOS>
# Target:i m not giving you any more money . <EOS>
# Decode:i m not going to be here .
# INFO:root:
# Source:nous avons l intention de gravir cette montagne . <EOS>
# Target:we are going to climb that mountain . <EOS> <PAD>
# Decode:we re working on his way .
# INFO:root:
# Source:il trouve toujours a redire aux autres . <EOS> <PAD>
# Target:he is always finding fault with other people . <EOS>
# Decode:he is always finding with his success .
# INFO:root:
# Source:je suis de bonne humeur aujourd hui . <EOS> <PAD>
# Target:i m in a good mood today . <EOS> <PAD>
# Decode:i m sure he will be late .
# INFO:root:
# Source:tu es celui qui m a formee . <EOS> <PAD>
# Target:you re the one who trained me . <EOS> <PAD>
# Decode:you re the one who trained me .
# INFO:root:
# Source:je suis sure qu elle partira tot . <EOS> <PAD>
# Target:i m sure she ll leave early . <EOS> <PAD>
# Decode:i m sure tom was happy .
# INFO:root:
# Source:vous etes trop sensible a la critique . <EOS> <PAD>
# Target:you are too sensitive to criticism . <EOS> <PAD> <PAD>
# Decode:you re the one who trained me .
# INFO:root:
# Source:il est aussi grand que son pere . <EOS> <PAD>
# Target:he is as tall as his father . <EOS> <PAD>
# Decode:he is more than a child of my father .
# INFO:root:
# Source:elle begaye quand elle se sent nerveuse . <EOS> <PAD>
# Target:she stammers when she feels nervous . <EOS> <PAD> <PAD>
# Decode:she is afraid of her car keys .
# INFO:root:
# Source:ils ne sont pas tous occupes . <EOS> <PAD> <PAD>
# Target:they re not all busy . <EOS> <PAD> <PAD> <PAD>
# Decode:they re not all alone .
# INFO:root:
# Source:je suis conscient de cette possibilite . <EOS> <PAD> <PAD>
# Target:i m aware of that possibility . <EOS> <PAD> <PAD>
# Decode:i m tired of his success .
# INFO:root:
# Source:je n y suis pas hostile . <EOS> <PAD> <PAD>
# Target:i m not unsympathetic . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m not your friend .
# INFO:root:
# Source:nous sommes a court d argent . <EOS> <PAD> <PAD>
# Target:we are short of money . <EOS> <PAD> <PAD> <PAD>
# Decode:we re all happy to go .
# INFO:root:
# Source:nous nous en sortons pas mal . <EOS> <PAD> <PAD>
# Target:we re doing well . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re going to be late .
# INFO:root:
# Source:je me rejouis de te revoir . <EOS> <PAD> <PAD>
# Target:i m glad to see you again . <EOS> <PAD>
# Decode:i m glad to see you again .
# INFO:root:
# Source:je n en suis pas partisan . <EOS> <PAD> <PAD>
# Target:i m not advocating that . <EOS> <PAD> <PAD> <PAD>
# Decode:i m not sure .
# INFO:root:
# Source:je suis ici pour te sauver . <EOS> <PAD> <PAD>
# Target:i m here to save you . <EOS> <PAD> <PAD>
# Decode:i m here to see you here .
# INFO:root:
# Source:vous etes trop stupide pour vivre . <EOS> <PAD> <PAD>
# Target:you re too stupid to live . <EOS> <PAD> <PAD>
# Decode:you re too old for me .
# INFO:root:
# Source:je chante avec mes enfants . <EOS> <PAD> <PAD> <PAD>
# Target:i am singing with my children . <EOS> <PAD> <PAD>
# Decode:i m sure tom will be late .
# INFO:root:
# Source:il est beau et intelligent . <EOS> <PAD> <PAD> <PAD>
# Target:he is handsome and clever . <EOS> <PAD> <PAD> <PAD>
# Decode:he s a very cheerful .
# INFO:root:
# Source:t es un mec bien . <EOS> <PAD> <PAD> <PAD>
# Target:you are a good person . <EOS> <PAD> <PAD> <PAD>
# Decode:you re a good person .
# INFO:root:
# Source:il est dans les affaires . <EOS> <PAD> <PAD> <PAD>
# Target:he is in business . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he s a gentleman .
# INFO:root:
# Source:nos scores sont tres serres . <EOS> <PAD> <PAD> <PAD>
# Target:we re very close . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:they re very busy .
# INFO:root:
# Source:il souffre d un rhume . <EOS> <PAD> <PAD> <PAD>
# Target:he is suffering from a cold . <EOS> <PAD> <PAD>
# Decode:he is a little bit tired .
# INFO:root:
# Source:je ne fais que regarder . <EOS> <PAD> <PAD> <PAD>
# Target:i m just looking around . <EOS> <PAD> <PAD> <PAD>
# Decode:i m not your friend .
# INFO:root:
# Source:nous sommes plutot occupees ici . <EOS> <PAD> <PAD> <PAD>
# Target:we re kind of busy here . <EOS> <PAD> <PAD>
# Decode:we re all happy to be here .
# INFO:root:
# Source:nous sommes toutes prisonnieres . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re all prisoners . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re all tired .
# INFO:root:
# Source:il manque de pratique . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s out of practice . <EOS> <PAD> <PAD> <PAD>
# Decode:he is fond of his success .
# INFO:root:
# Source:j ai terriblement faim . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i am terribly hungry . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m afraid of it .
# INFO:root:
# Source:vous etes fort genereux . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very generous . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very sophisticated .
# INFO:root:
# Source:nous sommes toutes la . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re all here . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re all here .
# INFO:root:
# Source:il cherche un emploi . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he is seeking employment . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he s a little bit in a gentleman .
# INFO:root:
# Source:nous y sommes pretes . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re ready for this . <EOS> <PAD> <PAD> <PAD>
# Decode:we re all happy .
# INFO:root:
# Source:tu es un puritain . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re a prude . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re a liar .
# INFO:root:
# Source:elle attend un enfant . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:she is expecting a child . <EOS> <PAD> <PAD> <PAD>
# Decode:she is a good person .
# INFO:root:
# Source:je suis alite . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i m in bed . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m a teacher .
# INFO:root:
# Source:ils sont speciaux . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:they re special . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:they re stunned .
# INFO:root:
# Source:nous sommes impuissants . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re helpless . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re stunned .
# INFO:root:
# Source:nous sommes amoureuses . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re in love . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re stunned .
# INFO:root:
# Source:tu es impatient . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re impatient . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re creative .
# INFO:root:
# Source:nous sommes synchronisees . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re in sync . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re stunned .
# INFO:root:
# Source:je suis fatigue ! <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i m sleepy ! <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:i m tired of my homework .
# INFO:root:
# Source:je l accorde . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i m not disagreeing . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m going to see it .
# INFO:root:LOSS: 1.6547383069992065
# 1it [00:00,  1.36it/s]
# torch.Size([50, 1, 10])
# INFO:root:LOSS: 1.794150710105896
# 2it [00:00,  2.40it/s]INFO:root:LOSS: 1.2881338596343994
# 3it [00:01,  3.29it/s]INFO:root:LOSS: 1.5032297372817993
# 4it [00:01,  3.94it/s]INFO:root:LOSS: 1.7671282291412354
# 5it [00:01,  4.53it/s]INFO:root:LOSS: 1.5518571138381958
# 6it [00:01,  4.95it/s]INFO:root:LOSS: 1.5442655086517334
# 7it [00:01,  5.25it/s]INFO:root:LOSS: 1.5410237312316895
# 8it [00:01,  5.42it/s]INFO:root:LOSS: 1.4644434452056885
# 9it [00:02,  5.56it/s]INFO:root:LOSS: 1.4768961668014526
# 10it [00:02,  5.66it/s]INFO:root:LOSS: 1.550896406173706
# 11it [00:02,  5.74it/s]INFO:root:LOSS: 1.562355637550354
# 12it [00:02,  5.73it/s]INFO:root:LOSS: 1.8581407070159912
# 13it [00:02,  5.78it/s]INFO:root:LOSS: 1.6983553171157837
# 14it [00:02,  5.84it/s]INFO:root:LOSS: 1.714818000793457
# 15it [00:03,  5.89it/s]INFO:root:LOSS: 1.6087932586669922
# 16it [00:03,  5.66it/s]INFO:root:LOSS: 1.3871632814407349
# 17it [00:03,  5.83it/s]INFO:root:LOSS: 1.4208863973617554
# 18it [00:03,  5.87it/s]INFO:root:LOSS: 1.7477868795394897
# 19it [00:03,  5.95it/s]INFO:root:LOSS: 1.6590863466262817
# 20it [00:03,  5.95it/s]INFO:root:LOSS: 1.5830719470977783
# 21it [00:04,  5.93it/s]INFO:root:LOSS: 1.6530741453170776
# 22it [00:04,  5.96it/s]INFO:root:LOSS: 1.64202880859375
# 23it [00:04,  5.99it/s]INFO:root:LOSS: 1.5805866718292236
# 24it [00:04,  5.99it/s]INFO:root:LOSS: 1.7670401334762573
# 25it [00:04,  6.05it/s]INFO:root:LOSS: 1.7496964931488037
# 26it [00:04,  6.07it/s]INFO:root:LOSS: 1.8854142427444458
# 27it [00:05,  6.05it/s]INFO:root:LOSS: 1.5814131498336792
# 28it [00:05,  5.94it/s]INFO:root:LOSS: 1.7913401126861572
# 29it [00:05,  5.99it/s]INFO:root:LOSS: 1.8955491781234741
# 30it [00:05,  5.93it/s]INFO:root:LOSS: 1.6377266645431519
# 31it [00:05,  5.95it/s]INFO:root:LOSS: 1.4482976198196411
# 32it [00:05,  6.00it/s]INFO:root:LOSS: 1.8223230838775635
# 33it [00:06,  5.93it/s]INFO:root:LOSS: 1.6868278980255127
# 34it [00:06,  5.89it/s]INFO:root:LOSS: 1.5864388942718506
# 35it [00:06,  5.94it/s]INFO:root:LOSS: 1.7390412092208862
# 36it [00:06,  6.02it/s]INFO:root:LOSS: 1.6095800399780273
# 37it [00:06,  6.03it/s]INFO:root:LOSS: 1.7711071968078613
# 38it [00:06,  6.06it/s]INFO:root:LOSS: 1.9255553483963013
# 39it [00:07,  6.07it/s]INFO:root:LOSS: 1.7331433296203613
# 40it [00:07,  6.01it/s]INFO:root:LOSS: 1.6203926801681519
# 41it [00:07,  6.03it/s]INFO:root:LOSS: 1.6104307174682617
# 42it [00:07,  6.27it/s]INFO:root:LOSS: 1.7516158819198608
# 43it [00:07,  6.30it/s]INFO:root:LOSS: 1.5791900157928467
# 44it [00:07,  6.29it/s]INFO:root:LOSS: 1.624571681022644
# 45it [00:08,  5.64it/s]INFO:root:LOSS: 1.79306960105896
# 46it [00:08,  5.29it/s]INFO:root:LOSS: 1.7407102584838867
# 47it [00:08,  5.12it/s]INFO:root:LOSS: 1.5156474113464355
# 48it [00:08,  4.74it/s]INFO:root:LOSS: 1.7115955352783203
# 49it [00:09,  4.63it/s]INFO:root:LOSS: 1.5471324920654297
# 50it [00:09,  4.46it/s]INFO:root:Decoding
#
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 79.37it/s]
# INFO:root:
# Source:je suis en train de changer de poste . <EOS>
# Target:i m between jobs . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m from the
# INFO:root:
# Source:elle plante des roses dans le jardin . <EOS> <PAD>
# Target:she s in the garden planting roses . <EOS> <PAD>
# Decode:she is going to win the
# INFO:root:
# Source:je vais vous conter un secret . <EOS> <PAD> <PAD>
# Target:i m going to tell you a secret . <EOS>
# Decode:i m going to be a teacher .
# INFO:root:
# Source:on est dans les clous . <EOS> <PAD> <PAD> <PAD>
# Target:we re on schedule . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re in trouble .
# INFO:root:
# Source:vous etes tres elegante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very stylish . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very timid .
# INFO:root:
# Source:c est un auteur . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s an author . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he is a student .
# INFO:root:
# Source:vous etes trop confiante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re too trusting . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re too trusting .
# INFO:root:
# Source:nous sommes bourrees . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re sloshed . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re too happy .
# INFO:root:
# Source:elles sont russes . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:they are russian . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:they re mine .
# INFO:root:
# Source:il est photogenique . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he is photogenic . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:he is a doctor .
# INFO:root:Decoding
# torch.Size([10, 1, 10])
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 56.93it/s]
# INFO:root:
# Source:il est trop jeune pour y aller seul . <EOS>
# Target:he is too young to go there alone . <EOS>
# Decode:he s too too old for me .
# INFO:root:
# Source:vous n etes pas aussi petit que moi . <EOS>
# Target:you aren t as short as i am . <EOS>
# Decode:you aren t as smart as me .
# INFO:root:
# Source:il n est plus aussi fort qu avant . <EOS>
# Target:he is not strong as before . <EOS> <PAD> <PAD>
# Decode:he is not as smart as me .
# INFO:root:
# Source:je suis desole de vous avoir hurle dessus . <EOS>
# Target:i m sorry i yelled at you . <EOS> <PAD>
# Decode:i m sorry to have bothered you .
# INFO:root:
# Source:je suis desolee . j ai oublie . <EOS> <PAD>
# Target:i m sorry . i forgot . <EOS> <PAD> <PAD>
# Decode:i m sorry .
# INFO:root:
# Source:je vais en europe la semaine prochaine . <EOS> <PAD>
# Target:i am going to europe next week . <EOS> <PAD>
# Decode:i m going to be a doctor .
# INFO:root:
# Source:elle a une peur bleue des chiens . <EOS> <PAD>
# Target:she s very afraid of dogs . <EOS> <PAD> <PAD>
# Decode:she is going to be a doctor .
# INFO:root:
# Source:je vais prendre conge pour cette nuit . <EOS> <PAD>
# Target:i m going to call it a night . <EOS>
# Decode:i m going to be your new head .
# INFO:root:
# Source:tu n as pas totalement tort . <EOS> <PAD> <PAD>
# Target:you re not entirely wrong . <EOS> <PAD> <PAD> <PAD>
# Decode:you re not going to go .
# INFO:root:
# Source:je me marie la semaine prochaine . <EOS> <PAD> <PAD>
# Target:i m getting married next week . <EOS> <PAD> <PAD>
# Decode:i m going to be a couple .
# INFO:root:
# Source:je viens tout juste de commencer . <EOS> <PAD> <PAD>
# Target:i m just getting started . <EOS> <PAD> <PAD> <PAD>
# Decode:i m not sure of it .
# INFO:root:
# Source:je ne suis absolument pas surpris . <EOS> <PAD> <PAD>
# Target:i am not in the least surprised . <EOS> <PAD>
# Decode:i m not a doctor .
# INFO:root:
# Source:elles sont bonnes toutes les deux . <EOS> <PAD> <PAD>
# Target:they are both good . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:they are all to go .
# INFO:root:
# Source:c est vraiment une bonne fille . <EOS> <PAD> <PAD>
# Target:she is a really good girl . <EOS> <PAD> <PAD>
# Decode:he is a very good boy .
# INFO:root:
# Source:j essaie simplement d etre amical . <EOS> <PAD> <PAD>
# Target:i m just trying to be friendly . <EOS> <PAD>
# Decode:i m afraid of all that .
# INFO:root:
# Source:il travaille de nuit ce soir . <EOS> <PAD> <PAD>
# Target:he is on night duty tonight . <EOS> <PAD> <PAD>
# Decode:he is afraid of his success .
# INFO:root:
# Source:il est professeur et moi aussi . <EOS> <PAD> <PAD>
# Target:he s a teacher and so am i . <EOS>
# Decode:he is an idiot !
# INFO:root:
# Source:il se moque toujours de moi . <EOS> <PAD> <PAD>
# Target:he is always making a fool of me . <EOS>
# Decode:he is always looking for me .
# INFO:root:
# Source:je suis plus intelligente que vous . <EOS> <PAD> <PAD>
# Target:i m smarter than you . <EOS> <PAD> <PAD> <PAD>
# Decode:i m as old as you .
# INFO:root:
# Source:c est bon pour moi . <EOS> <PAD> <PAD> <PAD>
# Target:i m fine with it . <EOS> <PAD> <PAD> <PAD>
# Decode:he is my friend of mine .
# INFO:root:
# Source:je suis dans la maison . <EOS> <PAD> <PAD> <PAD>
# Target:i m at home . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m in the same .
# INFO:root:
# Source:nous sommes parfaitement en securite . <EOS> <PAD> <PAD> <PAD>
# Target:we re perfectly safe . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re all alone .
# INFO:root:
# Source:je ne me dispute pas . <EOS> <PAD> <PAD> <PAD>
# Target:i m not arguing . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m not going .
# INFO:root:
# Source:vous n etes pas gentil . <EOS> <PAD> <PAD> <PAD>
# Target:you are not kind . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re not safe .
# INFO:root:
# Source:ils sont tous a moi . <EOS> <PAD> <PAD> <PAD>
# Target:they re all mine . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:they are all alike to me .
# INFO:root:
# Source:j ai repris le business . <EOS> <PAD> <PAD> <PAD>
# Target:i m back in business . <EOS> <PAD> <PAD> <PAD>
# Decode:i m still waiting .
# INFO:root:
# Source:tu es un sacre menteur . <EOS> <PAD> <PAD> <PAD>
# Target:you re such a liar . <EOS> <PAD> <PAD> <PAD>
# Decode:you re a wonderful friend .
# INFO:root:
# Source:vous etes parfois si pueril . <EOS> <PAD> <PAD> <PAD>
# Target:you are so childish sometimes . <EOS> <PAD> <PAD> <PAD>
# Decode:you re so talented .
# INFO:root:
# Source:c est toi la doyenne . <EOS> <PAD> <PAD> <PAD>
# Target:you re the oldest . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re the oldest .
# INFO:root:
# Source:vous n etes pas mort . <EOS> <PAD> <PAD> <PAD>
# Target:you re not dead . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re not being rational .
# INFO:root:
# Source:elle m a soudainement embrasse . <EOS> <PAD> <PAD> <PAD>
# Target:she suddenly kissed me . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:she is looking for her .
# INFO:root:
# Source:je vais m habiller . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i am going to get dressed . <EOS> <PAD> <PAD>
# Decode:i m going to go .
# INFO:root:
# Source:nous sommes en couple . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re a couple . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re all alone .
# INFO:root:
# Source:je viens de portugal . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i am from portugal . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m from england .
# INFO:root:
# Source:je suis assez fatiguee . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m quite tired . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m in trouble .
# INFO:root:
# Source:je m en contente . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m happy with it . <EOS> <PAD> <PAD> <PAD>
# Decode:i m going to go .
# INFO:root:
# Source:c est un aine . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s a senior . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he is a student .
# INFO:root:
# Source:elle sourit avec bonheur . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:she smiled happily . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:she is fond of her .
# INFO:root:
# Source:vous etes fort sceptique . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very skeptical . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very timid .
# INFO:root:
# Source:je requiers votre aide . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m asking you for your help . <EOS> <PAD>
# Decode:i m going to be your friend .
# INFO:root:
# Source:tu vas le regretter . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re going to regret this . <EOS> <PAD> <PAD>
# Decode:you re going to go .
# INFO:root:
# Source:nous sommes tous decus . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re all disappointed . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re all alone .
# INFO:root:
# Source:je vais mieux . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i am better . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:i m going to go .
# INFO:root:
# Source:tu es talentueuse . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re talented . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re big .
# INFO:root:
# Source:il est scientifique . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he is a scientist . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he is a teacher .
# INFO:root:
# Source:ils nous attendent . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:they re waiting for us . <EOS> <PAD> <PAD> <PAD>
# Decode:they re going to go .
# INFO:root:
# Source:elle est deprimee . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:she s depressed . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:she is a doctor .
# INFO:root:
# Source:tu es bonne . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you are good . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re a liar .
# INFO:root:
# Source:nous sommes seules . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re alone . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re being watched .
# INFO:root:
# Source:ils mentent tous . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:they re all lying . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:they re all waiting .
# INFO:root:LOSS: 1.4502595663070679
# 51it [00:10,  2.51it/s]
# torch.Size([50, 1, 10])
# INFO:root:LOSS: 1.7222212553024292
# 52it [00:10,  2.70it/s]INFO:root:LOSS: 1.5441803932189941
# 53it [00:10,  3.09it/s]INFO:root:LOSS: 1.702142596244812
# 54it [00:10,  3.45it/s]INFO:root:LOSS: 1.7507739067077637
# 55it [00:11,  3.74it/s]INFO:root:LOSS: 1.6751705408096313
# 56it [00:11,  3.99it/s]INFO:root:LOSS: 1.8673774003982544
# 57it [00:11,  4.15it/s]INFO:root:LOSS: 1.6909399032592773
# 58it [00:11,  4.44it/s]INFO:root:LOSS: 1.4370381832122803
# 59it [00:11,  4.83it/s]INFO:root:LOSS: 1.45207679271698
# 60it [00:12,  5.10it/s]INFO:root:LOSS: 1.5548020601272583
# 61it [00:12,  5.34it/s]INFO:root:LOSS: 1.7685588598251343
# 62it [00:12,  5.55it/s]INFO:root:LOSS: 1.7755775451660156
# 63it [00:12,  5.66it/s]INFO:root:LOSS: 1.5167577266693115
# 64it [00:12,  5.78it/s]INFO:root:LOSS: 1.8384150266647339
# 65it [00:12,  5.87it/s]INFO:root:LOSS: 1.6775932312011719
# 66it [00:12,  5.94it/s]INFO:root:LOSS: 1.5114439725875854
# 67it [00:13,  5.95it/s]INFO:root:LOSS: 1.786668300628662
# 68it [00:13,  6.05it/s]INFO:root:LOSS: 1.6844608783721924
# 69it [00:13,  5.96it/s]INFO:root:LOSS: 1.6734297275543213
# 70it [00:13,  5.99it/s]INFO:root:LOSS: 1.7047991752624512
# 71it [00:13,  6.13it/s]INFO:root:LOSS: 1.6231178045272827
# 72it [00:13,  6.18it/s]INFO:root:LOSS: 1.57782781124115
# 73it [00:14,  6.18it/s]INFO:root:LOSS: 1.5240740776062012
# 74it [00:14,  6.20it/s]INFO:root:LOSS: 1.7109163999557495
# 75it [00:14,  6.11it/s]INFO:root:LOSS: 1.5177927017211914
# 76it [00:14,  6.17it/s]INFO:root:LOSS: 1.863803744316101
# 77it [00:14,  6.22it/s]INFO:root:LOSS: 1.479540467262268
# 78it [00:14,  6.23it/s]INFO:root:LOSS: 1.709479570388794
# 79it [00:15,  6.25it/s]INFO:root:LOSS: 1.7440335750579834
# 80it [00:15,  6.21it/s]INFO:root:LOSS: 1.6952190399169922
# 81it [00:15,  6.24it/s]INFO:root:LOSS: 1.5991185903549194
# 82it [00:15,  6.16it/s]INFO:root:LOSS: 1.5205756425857544
# 83it [00:15,  6.22it/s]INFO:root:LOSS: 1.6765928268432617
# 84it [00:15,  6.21it/s]INFO:root:LOSS: 1.5692232847213745
# 85it [00:16,  6.21it/s]INFO:root:LOSS: 1.6032809019088745
# 86it [00:16,  6.09it/s]INFO:root:LOSS: 1.4236488342285156
# 87it [00:16,  6.13it/s]INFO:root:LOSS: 1.576996088027954
# 88it [00:16,  6.03it/s]INFO:root:LOSS: 1.566053032875061
# 89it [00:16,  6.10it/s]INFO:root:LOSS: 1.6979619264602661
# 90it [00:16,  6.14it/s]INFO:root:LOSS: 1.6577318906784058
# 91it [00:17,  6.18it/s]INFO:root:LOSS: 1.654159426689148
# 92it [00:17,  6.05it/s]INFO:root:LOSS: 1.5413392782211304
# 93it [00:17,  6.13it/s]INFO:root:LOSS: 1.5558639764785767
# 94it [00:17,  5.99it/s]INFO:root:LOSS: 1.682213306427002
# 95it [00:17,  6.06it/s]INFO:root:LOSS: 1.6542229652404785
# 96it [00:17,  6.07it/s]INFO:root:LOSS: 1.5617945194244385
# 97it [00:18,  6.07it/s]INFO:root:LOSS: 1.5712571144104004
# 98it [00:18,  6.08it/s]INFO:root:LOSS: 1.5891914367675781
# 99it [00:18,  6.06it/s]INFO:root:LOSS: 1.5410311222076416
# 100it [00:18,  5.97it/s]INFO:root:Decoding
#
# 100%|██████████| 10/10 [00:00<00:00, 114.99it/s]
# INFO:root:
# Source:je suis en train de changer de poste . <EOS>
# Target:i m between jobs . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m from the i of the same .
# INFO:root:
# Source:elle plante des roses dans le jardin . <EOS> <PAD>
# Target:she s in the garden planting roses . <EOS> <PAD>
# Decode:she is always complaining .
# INFO:root:
# Source:je vais vous conter un secret . <EOS> <PAD> <PAD>
# Target:i m going to tell you a secret . <EOS>
# Decode:i m going to have a car .
# INFO:root:
# Source:on est dans les clous . <EOS> <PAD> <PAD> <PAD>
# Target:we re on schedule . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re in the same .
# INFO:root:
# Source:c est un auteur . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s an author . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he is a gentleman .
# INFO:root:
# Source:vous etes tres elegante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very stylish . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very brave .
# INFO:root:
# Source:vous etes trop confiante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re too trusting . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re too trusting .
# INFO:root:
# Source:nous sommes bourrees . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re sloshed . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re ready .
# INFO:root:
# Source:il est photogenique . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he is photogenic . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:he s a teacher .
# INFO:root:
# Source:elles sont russes . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:they are russian . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:they re students .
# INFO:root:Decoding
# torch.Size([10, 1, 10])
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 74.77it/s]
# INFO:root:
# Source:elle est en train de coucher les enfants . <EOS>
# Target:she s putting the children to bed . <EOS> <PAD>
# Decode:she is in the mood of the result .
# INFO:root:
# Source:je suis desolee si je vous ai derangees . <EOS>
# Target:i m sorry if i disturbed you . <EOS> <PAD>
# Decode:i m sorry if i frightened you .
# INFO:root:
# Source:il est en train d ecrire un roman . <EOS>
# Target:he is writing a novel . <EOS> <PAD> <PAD> <PAD>
# Decode:he is a gentleman .
# INFO:root:
# Source:vous etes deux fois plus fortes que moi . <EOS>
# Target:you are twice as strong as i am . <EOS>
# Decode:you re smarter than me .
# INFO:root:
# Source:il est en colere apres tout le monde . <EOS>
# Target:he s mad at everyone . <EOS> <PAD> <PAD> <PAD>
# Decode:he is in the same age .
# INFO:root:
# Source:tu as le meme age que mon fils . <EOS>
# Target:you re the same age as my son . <EOS>
# Decode:you re the one who trained me .
# INFO:root:
# Source:je me rejouis de vous avoir finalement rencontree . <EOS>
# Target:i m glad to finally meet you . <EOS> <PAD>
# Decode:i m glad to see you re happy .
# INFO:root:
# Source:elle a une peur bleue des chiens . <EOS> <PAD>
# Target:she s very afraid of dogs . <EOS> <PAD> <PAD>
# Decode:she is always complaining .
# INFO:root:
# Source:nous appartenons tous a la meme equipe . <EOS> <PAD>
# Target:we re all on the same team . <EOS> <PAD>
# Decode:we re all the same team .
# INFO:root:
# Source:c est lui le bouc emissaire . <EOS> <PAD> <PAD>
# Target:he s the scapegoat . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:she is the same age .
# INFO:root:
# Source:vous etes trop suspicieuses de tout . <EOS> <PAD> <PAD>
# Target:you re too suspicious about everything . <EOS> <PAD> <PAD>
# Decode:you re too young to go .
# INFO:root:
# Source:nous attendons les vacances avec impatience . <EOS> <PAD> <PAD>
# Target:we are looking forward to the holidays . <EOS> <PAD>
# Decode:we re all on the same team .
# INFO:root:
# Source:je ne vais pas m impliquer . <EOS> <PAD> <PAD>
# Target:i m not going to get involved . <EOS> <PAD>
# Decode:i m not going to get involved .
# INFO:root:
# Source:je suis a court d essence . <EOS> <PAD> <PAD>
# Target:i m out of gas . <EOS> <PAD> <PAD> <PAD>
# Decode:i m from the same .
# INFO:root:
# Source:il est plus intelligent que moi . <EOS> <PAD> <PAD>
# Target:he is more clever than me . <EOS> <PAD> <PAD>
# Decode:he is as tall as me .
# INFO:root:
# Source:je ne suis pas ton ennemi . <EOS> <PAD> <PAD>
# Target:i am not your enemy . <EOS> <PAD> <PAD> <PAD>
# Decode:i m not your friend .
# INFO:root:
# Source:je suis dispose a me repentir . <EOS> <PAD> <PAD>
# Target:i m ready to make amends . <EOS> <PAD> <PAD>
# Decode:i m sorry to have bothered .
# INFO:root:
# Source:il travaille de nuit ce soir . <EOS> <PAD> <PAD>
# Target:he is on night duty tonight . <EOS> <PAD> <PAD>
# Decode:he is afraid of his success .
# INFO:root:
# Source:il est fier d etre medecin . <EOS> <PAD> <PAD>
# Target:he is proud of being a doctor . <EOS> <PAD>
# Decode:he is sure to be a gentleman .
# INFO:root:
# Source:nous avons presque acheve ce travail . <EOS> <PAD> <PAD>
# Target:we re just about finished with this job . <EOS>
# Decode:we re going to have to have to be here
# INFO:root:
# Source:il est doue aux jeux video . <EOS> <PAD> <PAD>
# Target:he s skilled at videogames . <EOS> <PAD> <PAD> <PAD>
# Decode:he is likely to go .
# INFO:root:
# Source:je suis occupe a mes devoirs . <EOS> <PAD> <PAD>
# Target:i m busy with my homework . <EOS> <PAD> <PAD>
# Decode:i m ready to see you .
# INFO:root:
# Source:je ne parle pas avec tom . <EOS> <PAD> <PAD>
# Target:i m not talking to tom . <EOS> <PAD> <PAD>
# Decode:i m not afraid of this .
# INFO:root:
# Source:je suis pret a y aller . <EOS> <PAD> <PAD>
# Target:i m ready to go . <EOS> <PAD> <PAD> <PAD>
# Decode:i m ready to go .
# INFO:root:
# Source:c est vous l institutrice . <EOS> <PAD> <PAD> <PAD>
# Target:you re the teacher . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re the oldest .
# INFO:root:
# Source:vous n etes pas invitees . <EOS> <PAD> <PAD> <PAD>
# Target:you aren t invited . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re not dead .
# INFO:root:
# Source:je vais ecrire une lettre . <EOS> <PAD> <PAD> <PAD>
# Target:i am going to write a letter . <EOS> <PAD>
# Decode:i m going to have a car .
# INFO:root:
# Source:tu es dans la merde . <EOS> <PAD> <PAD> <PAD>
# Target:you re in big trouble . <EOS> <PAD> <PAD> <PAD>
# Decode:you re the oldest .
# INFO:root:
# Source:nous faisons beaucoup de choses . <EOS> <PAD> <PAD> <PAD>
# Target:we re getting a lot of things done . <EOS>
# Decode:we re very busy .
# INFO:root:
# Source:c est une infirmiere attitree . <EOS> <PAD> <PAD> <PAD>
# Target:she is qualified as a nurse . <EOS> <PAD> <PAD>
# Decode:she is a man of us .
# INFO:root:
# Source:tu n es pas normale . <EOS> <PAD> <PAD> <PAD>
# Target:you re not normal . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re not dressed .
# INFO:root:
# Source:j attends mon tour . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m waiting my turn . <EOS> <PAD> <PAD> <PAD>
# Decode:i m looking forward to my friends .
# INFO:root:
# Source:elle chantait assez bien . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:she sang pretty well . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:she is good at him .
# INFO:root:
# Source:je pars ce soir . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m departing this evening . <EOS> <PAD> <PAD> <PAD>
# Decode:i m done with this .
# INFO:root:
# Source:on m a promue . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m being promoted . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m very hungry .
# INFO:root:
# Source:tu es nerveusement use . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re a nervous wreck . <EOS> <PAD> <PAD> <PAD>
# Decode:you re the teacher .
# INFO:root:
# Source:ce sont des espionnes . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:they re spies . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:they re students .
# INFO:root:
# Source:nous sommes trop occupees . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re too busy . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re too old .
# INFO:root:
# Source:il est completement fou . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s an absolute fool . <EOS> <PAD> <PAD> <PAD>
# Decode:he is good at tennis .
# INFO:root:
# Source:je vais me battre . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m going to fight . <EOS> <PAD> <PAD> <PAD>
# Decode:i m going to get a lot .
# INFO:root:
# Source:nous sommes trop vieux . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re too old . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re too old .
# INFO:root:
# Source:tu es l instituteur . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re the teacher . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re the teacher .
# INFO:root:
# Source:elles sont toutes terrifiees . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:they re all terrified . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:they re all here .
# INFO:root:
# Source:vous etes fiables . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re reliable . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re extroverted .
# INFO:root:
# Source:tu te ridiculises . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re embarrassing yourself . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re going to go .
# INFO:root:
# Source:il est pauvre . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he is poor . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:he s a teacher .
# INFO:root:
# Source:il se rapproche . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he s coming closer . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he is always dressed .
# INFO:root:
# Source:je suis innocent . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i m an innocent man . <EOS> <PAD> <PAD> <PAD>
# Decode:i m ready .
# INFO:root:
# Source:tu es bavarde . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re talkative . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re extroverted .
# INFO:root:
# Source:nous nous deshabillons . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re undressing . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re going to get involved .
# INFO:root:LOSS: 1.6184332370758057
# 101it [00:19,  3.32it/s]
# torch.Size([50, 1, 10])
# INFO:root:LOSS: 1.7163394689559937
# 102it [00:19,  3.53it/s]INFO:root:LOSS: 1.4342728853225708
# 103it [00:19,  3.98it/s]INFO:root:LOSS: 1.627448558807373
# 104it [00:19,  4.44it/s]INFO:root:LOSS: 1.5521769523620605
# 105it [00:19,  4.84it/s]INFO:root:LOSS: 1.561543583869934
# 106it [00:20,  5.23it/s]INFO:root:LOSS: 1.5625965595245361
# 107it [00:20,  5.40it/s]INFO:root:LOSS: 1.508968472480774
# 108it [00:20,  5.58it/s]INFO:root:LOSS: 1.619600772857666
# 109it [00:20,  5.67it/s]INFO:root:LOSS: 1.8077977895736694
# 110it [00:20,  5.83it/s]INFO:root:LOSS: 1.6239017248153687
# 111it [00:20,  5.89it/s]INFO:root:LOSS: 1.6678171157836914
# 112it [00:21,  5.99it/s]INFO:root:LOSS: 1.6273361444473267
# 113it [00:21,  5.98it/s]INFO:root:LOSS: 1.4615520238876343
# 114it [00:21,  5.91it/s]INFO:root:LOSS: 1.4285868406295776
# 115it [00:21,  6.07it/s]INFO:root:LOSS: 1.657900333404541
# 116it [00:21,  5.42it/s]INFO:root:LOSS: 1.5906797647476196
# 117it [00:22,  5.10it/s]INFO:root:LOSS: 1.7435283660888672
# 118it [00:22,  4.92it/s]INFO:root:LOSS: 1.566055178642273
# 119it [00:22,  4.88it/s]INFO:root:LOSS: 1.6999385356903076
# 120it [00:22,  4.79it/s]INFO:root:LOSS: 1.7622663974761963
# 121it [00:22,  4.75it/s]INFO:root:LOSS: 1.6860672235488892
# 122it [00:23,  4.71it/s]INFO:root:LOSS: 1.517884612083435
# 123it [00:23,  4.77it/s]INFO:root:LOSS: 1.6045814752578735
# 124it [00:23,  4.80it/s]INFO:root:LOSS: 1.5260274410247803
# 125it [00:23,  4.63it/s]INFO:root:LOSS: 1.3930611610412598
# 126it [00:23,  4.64it/s]INFO:root:LOSS: 1.4437657594680786
# 127it [00:24,  4.64it/s]INFO:root:LOSS: 1.5822771787643433
# 128it [00:24,  4.58it/s]INFO:root:LOSS: 1.482202410697937
# 129it [00:24,  4.57it/s]INFO:root:LOSS: 1.6117050647735596
# 130it [00:24,  4.50it/s]INFO:root:LOSS: 1.6371183395385742
# 131it [00:25,  4.72it/s]INFO:root:LOSS: 1.6832976341247559
# 132it [00:25,  5.02it/s]INFO:root:LOSS: 1.479870080947876
# 133it [00:25,  5.25it/s]INFO:root:LOSS: 1.7929103374481201
# 134it [00:25,  5.46it/s]INFO:root:LOSS: 1.5644187927246094
# 135it [00:25,  5.63it/s]INFO:root:LOSS: 1.635822057723999
# 136it [00:25,  5.76it/s]INFO:root:LOSS: 1.5759634971618652
# 137it [00:26,  5.85it/s]INFO:root:LOSS: 1.504576563835144
# 138it [00:26,  5.87it/s]INFO:root:LOSS: 1.533927321434021
# 139it [00:26,  5.84it/s]INFO:root:LOSS: 1.6994314193725586
# 140it [00:26,  5.88it/s]INFO:root:LOSS: 1.6260930299758911
# 141it [00:26,  6.13it/s]INFO:root:LOSS: 1.2443064451217651
# 142it [00:26,  6.26it/s]INFO:root:LOSS: 1.5682491064071655
# 143it [00:27,  6.13it/s]INFO:root:LOSS: 1.5016292333602905
# 144it [00:27,  6.12it/s]INFO:root:LOSS: 1.5843186378479004
# 145it [00:27,  6.07it/s]INFO:root:LOSS: 1.6775295734405518
# 146it [00:27,  5.93it/s]INFO:root:LOSS: 1.5675052404403687
# 147it [00:27,  6.01it/s]INFO:root:LOSS: 1.40927255153656
# 148it [00:27,  6.01it/s]INFO:root:LOSS: 1.4913259744644165
# 149it [00:28,  6.09it/s]INFO:root:LOSS: 1.5951673984527588
# 150it [00:28,  6.09it/s]INFO:root:Decoding
#
# 100%|██████████| 10/10 [00:00<00:00, 113.07it/s]
# INFO:root:
# Source:je suis en train de changer de poste . <EOS>
# Target:i m between jobs . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m from the exam .
# INFO:root:
# Source:elle plante des roses dans le jardin . <EOS> <PAD>
# Target:she s in the garden planting roses . <EOS> <PAD>
# Decode:she is always complaining in the job .
# INFO:root:
# Source:je vais vous conter un secret . <EOS> <PAD> <PAD>
# Target:i m going to tell you a secret . <EOS>
# Decode:i m going to be your car .
# INFO:root:
# Source:on est dans les clous . <EOS> <PAD> <PAD> <PAD>
# Target:we re on schedule . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re in the same .
# INFO:root:
# Source:c est un auteur . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s an author . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he is a gentleman .
# INFO:root:
# Source:vous etes tres elegante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very stylish . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very brave .
# INFO:root:
# Source:vous etes trop confiante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re too trusting . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re too skinny .
# INFO:root:
# Source:il est photogenique . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he is photogenic . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:he is a teacher .
# INFO:root:
# Source:elles sont russes . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:they are russian . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:they re crazy .
# INFO:root:
# Source:nous sommes bourrees . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re sloshed . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re ready we .
# torch.Size([10, 1, 10])
# INFO:root:Decoding
#
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 71.71it/s]
# INFO:root:
# Source:je me rejouis de t avoir finalement rencontre . <EOS>
# Target:i m glad to finally meet you . <EOS> <PAD>
# Decode:i m glad i invited you .
# INFO:root:
# Source:je suis tres content de ma nouvelle voiture . <EOS>
# Target:i am really pleased with my new car . <EOS>
# Decode:i m very glad to have a lot of money
# INFO:root:
# Source:je suis desole je ne gobe pas ca . <EOS>
# Target:i m sorry i don t buy it . <EOS>
# Decode:i m sorry i don t recognize you .
# INFO:root:
# Source:je ne suis pas aussi maligne que toi . <EOS>
# Target:i m not as smart as you . <EOS> <PAD>
# Decode:i m not as smart as you .
# INFO:root:
# Source:je n en ai pas fini avec vous . <EOS>
# Target:i m not finished with you . <EOS> <PAD> <PAD>
# Decode:i m not afraid of you .
# INFO:root:
# Source:vous n etes pas aussi malin que moi . <EOS>
# Target:you re not as smart as me . <EOS> <PAD>
# Decode:you re not as smart as me .
# INFO:root:
# Source:je suis content que tu sois toujours la . <EOS>
# Target:i m glad you re still here . <EOS> <PAD>
# Decode:i m glad you re here .
# INFO:root:
# Source:il est un critique des autres tres irritant . <EOS>
# Target:he is a very irritating critic of others . <EOS>
# Decode:he is a very good at tennis .
# INFO:root:
# Source:tu ne comptes pas au nombre des suspects . <EOS>
# Target:you re not a suspect . <EOS> <PAD> <PAD> <PAD>
# Decode:you re not going to make the truth .
# INFO:root:
# Source:je suis si heureux pour vous tom . <EOS> <PAD>
# Target:i m so happy for you tom . <EOS> <PAD>
# Decode:i m happy for you here .
# INFO:root:
# Source:il est au bout de ses forces . <EOS> <PAD>
# Target:he s on his last legs . <EOS> <PAD> <PAD>
# Decode:he is likely to win the game .
# INFO:root:
# Source:c est moi le patron par ici . <EOS> <PAD>
# Target:i m the boss around here . <EOS> <PAD> <PAD>
# Decode:i m the one who trained me .
# INFO:root:
# Source:il perd tout le temps son parapluie . <EOS> <PAD>
# Target:he is always losing his umbrella . <EOS> <PAD> <PAD>
# Decode:he is always complaining in the game .
# INFO:root:
# Source:vous n etes pas censees fumer ici . <EOS> <PAD>
# Target:you are not supposed to smoke here . <EOS> <PAD>
# Decode:you re not supposed to be here .
# INFO:root:
# Source:je suis presque aussi grand que tom . <EOS> <PAD>
# Target:i m almost as tall as tom . <EOS> <PAD>
# Decode:i m glad you re here .
# INFO:root:
# Source:j etudie avec beaucoup d assiduite . <EOS> <PAD> <PAD>
# Target:i m studying very hard . <EOS> <PAD> <PAD> <PAD>
# Decode:i m getting happy with my job .
# INFO:root:
# Source:il est capitaine d une equipe . <EOS> <PAD> <PAD>
# Target:he s the captain of a team . <EOS> <PAD>
# Decode:he is a good at tennis .
# INFO:root:
# Source:vous etes blanc comme un drap . <EOS> <PAD> <PAD>
# Target:you are as white as a sheet . <EOS> <PAD>
# Decode:you re a good cook .
# INFO:root:
# Source:il est maintenant etudiant en faculte . <EOS> <PAD> <PAD>
# Target:he s now a college student . <EOS> <PAD> <PAD>
# Decode:he is a good at home .
# INFO:root:
# Source:je suis plutot occupee ce soir . <EOS> <PAD> <PAD>
# Target:i m kind of busy tonight . <EOS> <PAD> <PAD>
# Decode:i m sure we can work this .
# INFO:root:
# Source:tu n y es pas bonne . <EOS> <PAD> <PAD>
# Target:you re not good at this . <EOS> <PAD> <PAD>
# Decode:you re not a doctor .
# INFO:root:
# Source:je ne vais pas signer ceci . <EOS> <PAD> <PAD>
# Target:i m not going to sign this . <EOS> <PAD>
# Decode:i m not going to make it .
# INFO:root:
# Source:c est vous la plus vieille . <EOS> <PAD> <PAD>
# Target:you re the oldest . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re the one who trained me .
# INFO:root:
# Source:il gagne deux fois mon salaire . <EOS> <PAD> <PAD>
# Target:he is earning twice my salary . <EOS> <PAD> <PAD>
# Decode:he is as tall as my sister .
# INFO:root:
# Source:c est une infirmiere attitree . <EOS> <PAD> <PAD> <PAD>
# Target:she is qualified as a nurse . <EOS> <PAD> <PAD>
# Decode:she is a good person .
# INFO:root:
# Source:il est suspecte de vol . <EOS> <PAD> <PAD> <PAD>
# Target:he is suspected of robbery . <EOS> <PAD> <PAD> <PAD>
# Decode:he is out of music .
# INFO:root:
# Source:nous ne sommes pas invites . <EOS> <PAD> <PAD> <PAD>
# Target:we re not invited . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re not alone .
# INFO:root:
# Source:elle est belle comme toujours . <EOS> <PAD> <PAD> <PAD>
# Target:she is as beautiful as ever . <EOS> <PAD> <PAD>
# Decode:she is always young at home .
# INFO:root:
# Source:j en ai tellement marre . <EOS> <PAD> <PAD> <PAD>
# Target:i m so sick of this . <EOS> <PAD> <PAD>
# Decode:i m sorry about my job .
# INFO:root:
# Source:je ne suis pas la . <EOS> <PAD> <PAD> <PAD>
# Target:i m not here . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m not your enemy .
# INFO:root:
# Source:je ne suis pas contente . <EOS> <PAD> <PAD> <PAD>
# Target:i m not happy . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m not your enemy .
# INFO:root:
# Source:elle a dit au revoir . <EOS> <PAD> <PAD> <PAD>
# Target:she said goodbye . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:she is fond of music .
# INFO:root:
# Source:je suis consciente des faits . <EOS> <PAD> <PAD> <PAD>
# Target:i m aware of the facts . <EOS> <PAD> <PAD>
# Decode:i m in trouble .
# INFO:root:
# Source:j attends ton aide . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m waiting for your help . <EOS> <PAD> <PAD>
# Decode:i m waiting for your help .
# INFO:root:
# Source:c est un renard . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:she is a fox . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he s a teacher .
# INFO:root:
# Source:tu es tres grossier . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very rude . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very brave .
# INFO:root:
# Source:tu es tres marrant . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very funny . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very brave .
# INFO:root:
# Source:nous sommes toutes ici . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re all here . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re all here .
# INFO:root:
# Source:vous etes tres occupee . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very busy . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very good .
# INFO:root:
# Source:vous etes tres indelicats . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you are very insensitive . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very brave .
# INFO:root:
# Source:je suis tres stricte . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m very strict . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m very happy .
# INFO:root:
# Source:vous etes tres grand . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very tall . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very brave .
# INFO:root:
# Source:il est en route . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s on his way . <EOS> <PAD> <PAD> <PAD>
# Decode:he is in danger .
# INFO:root:
# Source:nous avons depasse cela . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re past that . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re going to have a lot .
# INFO:root:
# Source:j ai une assuetude . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m addicted . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:i m a little hungry .
# INFO:root:
# Source:vous etes nerveusement usee . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re a nervous wreck . <EOS> <PAD> <PAD> <PAD>
# Decode:you re the one .
# INFO:root:
# Source:tu es bougon . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re grumpy . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re skinny .
# INFO:root:
# Source:je suis claustrophobe . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i m claustrophobic . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:i m exhausted .
# INFO:root:
# Source:vous etes endurant . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re resilient . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re skinny .
# INFO:root:
# Source:je suis puni . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i m being punished . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m exhausted .
# INFO:root:LOSS: 1.5165752172470093
# 151it [00:28,  2.90it/s]
# torch.Size([50, 1, 10])
# INFO:root:LOSS: 1.5205920934677124
# 152it [00:29,  3.17it/s]INFO:root:LOSS: 1.5881131887435913
# 153it [00:29,  3.67it/s]INFO:root:LOSS: 1.6063024997711182
# 154it [00:29,  4.15it/s]INFO:root:LOSS: 1.6498662233352661
# 155it [00:29,  4.70it/s]INFO:root:LOSS: 1.4198013544082642
# 156it [00:29,  4.96it/s]INFO:root:LOSS: 1.5303541421890259
# 157it [00:30,  5.26it/s]INFO:root:LOSS: 1.5197635889053345
# 158it [00:30,  5.40it/s]INFO:root:LOSS: 1.4831277132034302
# 159it [00:30,  5.56it/s]INFO:root:LOSS: 1.8545912504196167
# ...
# Decode:i m resentful .
# INFO:root:
# Source:nous sommes des prisonnieres . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:we re prisoners . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re prisoners .
# INFO:root:
# Source:il est tres jeune . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he is very young . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he is very young .
# INFO:root:
# Source:vous etes tellement idiots ! <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you are so stupid . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re so predictable .
# INFO:root:
# Source:je suis en vacances . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m on holiday . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m on vacation .
# INFO:root:
# Source:tu joues au chef . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re bossy . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re bossy .
# INFO:root:
# Source:je suis toujours celibataire . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m still single . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m still single .
# INFO:root:
# Source:je suis en retard . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m late . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:i m late .
# INFO:root:
# Source:vous etes le chef . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re the leader . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re the leader .
# INFO:root:
# Source:je suis ton amie . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m your friend . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m your friend .
# INFO:root:
# Source:nous sommes affames . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re starved . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re unlucky .
# INFO:root:
# Source:vous etes veinard . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re in luck . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re in luck .
# INFO:root:
# Source:nous sommes heureux . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we are happy . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re happy .
# INFO:root:
# Source:elle ment mal . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:she s a bad liar . <EOS> <PAD> <PAD> <PAD>
# Decode:she s a bad liar .
# INFO:root:
# Source:je suis desole . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i am sorry . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:i m sorry .
# INFO:root:
# Source:nous sommes enseignants . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we are teachers . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re powerless .
# INFO:root:LOSS: 0.2332538664340973
# 151it [00:30,  2.94it/s]
# torch.Size([50, 1, 10])
# INFO:root:LOSS: 0.26705804467201233
# 152it [00:31,  3.16it/s]INFO:root:LOSS: 0.27749013900756836
# 153it [00:31,  3.57it/s]INFO:root:LOSS: 0.22979800403118134
# 154it [00:31,  3.82it/s]INFO:root:LOSS: 0.23311296105384827
# 155it [00:31,  4.08it/s]INFO:root:LOSS: 0.22345323860645294
# 156it [00:31,  4.32it/s]INFO:root:LOSS: 0.2357054501771927
# 157it [00:32,  4.70it/s]INFO:root:LOSS: 0.22665855288505554
# 158it [00:32,  4.99it/s]INFO:root:LOSS: 0.2240537703037262
# 159it [00:32,  5.23it/s]INFO:root:LOSS: 0.18016941845417023
# 160it [00:32,  5.46it/s]INFO:root:LOSS: 0.25424787402153015
# 161it [00:32,  5.66it/s]INFO:root:LOSS: 0.28586047887802124
# 162it [00:32,  5.84it/s]INFO:root:LOSS: 0.24301795661449432
# 163it [00:33,  5.86it/s]INFO:root:LOSS: 0.22776396572589874
# 164it [00:33,  5.93it/s]INFO:root:LOSS: 0.27861833572387695
# 165it [00:33,  5.82it/s]INFO:root:LOSS: 0.2567932903766632
# 166it [00:33,  5.96it/s]INFO:root:LOSS: 0.21987946331501007
# 167it [00:33,  5.98it/s]INFO:root:LOSS: 0.2638470232486725
# 168it [00:33,  6.03it/s]INFO:root:LOSS: 0.27910229563713074
# 169it [00:34,  6.05it/s]INFO:root:LOSS: 0.20073403418064117
# 170it [00:34,  6.06it/s]INFO:root:LOSS: 0.28148728609085083
# 171it [00:34,  6.07it/s]INFO:root:LOSS: 0.3342309594154358
# 172it [00:34,  6.24it/s]INFO:root:LOSS: 0.24419915676116943
# 173it [00:34,  6.21it/s]INFO:root:LOSS: 0.22546473145484924
# 174it [00:34,  6.16it/s]INFO:root:LOSS: 0.24383066594600677
# 175it [00:35,  6.15it/s]INFO:root:LOSS: 0.2576603591442108
# 176it [00:35,  6.07it/s]INFO:root:LOSS: 0.2583101689815521
# 177it [00:35,  5.89it/s]INFO:root:LOSS: 0.24277304112911224
# 178it [00:35,  5.80it/s]INFO:root:LOSS: 0.21223299205303192
# 179it [00:35,  5.86it/s]INFO:root:LOSS: 0.2158481925725937
# 180it [00:35,  5.95it/s]INFO:root:LOSS: 0.23821455240249634
# 181it [00:36,  6.03it/s]INFO:root:LOSS: 0.2294853925704956
# 182it [00:36,  6.07it/s]INFO:root:LOSS: 0.2458566129207611
# 183it [00:36,  6.21it/s]INFO:root:LOSS: 0.2628553807735443
# 184it [00:36,  6.13it/s]INFO:root:LOSS: 0.2564946711063385
# 185it [00:36,  6.08it/s]INFO:root:LOSS: 0.25610679388046265
# 186it [00:36,  6.04it/s]INFO:root:LOSS: 0.29333531856536865
# 187it [00:37,  6.00it/s]INFO:root:LOSS: 0.20438942313194275
# 188it [00:37,  5.92it/s]INFO:root:LOSS: 0.22971518337726593
# 189it [00:37,  5.88it/s]INFO:root:LOSS: 0.24803631007671356
# 190it [00:37,  5.84it/s]INFO:root:LOSS: 0.29916295409202576
# 191it [00:37,  5.98it/s]INFO:root:LOSS: 0.1691087782382965
# 192it [00:37,  6.00it/s]INFO:root:LOSS: 0.25730812549591064
# 193it [00:38,  5.93it/s]INFO:root:LOSS: 0.3133752644062042
# 194it [00:38,  5.44it/s]INFO:root:LOSS: 0.255687952041626
# 195it [00:38,  5.17it/s]INFO:root:LOSS: 0.19714632630348206
# 196it [00:38,  4.94it/s]INFO:root:LOSS: 0.229954332113266
# 197it [00:38,  4.88it/s]INFO:root:LOSS: 0.2747478187084198
# 198it [00:39,  4.63it/s]INFO:root:LOSS: 0.28895458579063416
# 199it [00:39,  4.50it/s]INFO:root:LOSS: 0.1880449652671814
# 200it [00:39,  4.36it/s]INFO:root:Decoding
#
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 73.48it/s]
# INFO:root:
# Source:je suis en train de changer de poste . <EOS>
# Target:i m between jobs . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m from kyoto .
# INFO:root:
# Source:elle plante des roses dans le jardin . <EOS> <PAD>
# Target:she s in the garden planting roses . <EOS> <PAD>
# Decode:she is living in the field of biology .
# INFO:root:
# Source:je vais vous conter un secret . <EOS> <PAD> <PAD>
# Target:i m going to tell you a secret . <EOS>
# Decode:i m going to tell you a secret .
# INFO:root:
# Source:on est dans les clous . <EOS> <PAD> <PAD> <PAD>
# Target:we re on schedule . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re in trouble .
# INFO:root:
# Source:vous etes tres elegante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very stylish . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very stylish .
# INFO:root:
# Source:vous etes trop confiante . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re too trusting . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re too skinny .
# INFO:root:
# Source:c est un auteur . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s an author . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he s a slacker .
# INFO:root:
# Source:il est photogenique . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he is photogenic . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:he s photogenic .
# INFO:root:
# Source:elles sont russes . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:they are russian . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:they re boring .
# INFO:root:
# Source:nous sommes bourrees . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re sloshed . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re plastered .
# INFO:root:Decoding
# torch.Size([10, 1, 10])
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 50.12it/s]
# INFO:root:
# Source:je n ai pas si soif que ca . <EOS>
# Target:i m not really that thirsty . <EOS> <PAD> <PAD>
# Decode:i m not really that thirsty .
# INFO:root:
# Source:ce sont celles qui veulent s y rendre . <EOS>
# Target:they are the ones who want to go . <EOS>
# Decode:they are the ones who want to go .
# INFO:root:
# Source:il est le meilleur joueur de notre equipe . <EOS>
# Target:he is the best player on our team . <EOS>
# Decode:he is the best player on our team .
# INFO:root:
# Source:je me rejouis que tu te portes mieux . <EOS>
# Target:i m glad you re doing better . <EOS> <PAD>
# Decode:i m glad you re doing better .
# INFO:root:
# Source:je dois dix mille dollars a mon oncle . <EOS>
# Target:i m in debt to my uncle for . <EOS>
# Decode:i m in debt to my uncle for .
# INFO:root:
# Source:je suis desole si je t ai effrayee . <EOS>
# Target:i m sorry if i frightened you . <EOS> <PAD>
# Decode:i m sorry if i frightened you .
# INFO:root:
# Source:nous sommes les voisins d a cote . <EOS> <PAD>
# Target:we are next door neighbors . <EOS> <PAD> <PAD> <PAD>
# Decode:we are next door neighbors .
# INFO:root:
# Source:elle est bien plus heureuse que lui . <EOS> <PAD>
# Target:she s much happier than him . <EOS> <PAD> <PAD>
# Decode:she s much heavier than him .
# INFO:root:
# Source:je suis desolee de t avoir blessee . <EOS> <PAD>
# Target:i m sorry i hurt you . <EOS> <PAD> <PAD>
# Decode:i m sorry i hurt you .
# INFO:root:
# Source:elle n est jamais a l heure . <EOS> <PAD>
# Target:she is never on time . <EOS> <PAD> <PAD> <PAD>
# Decode:she s never been in the hospital .
# INFO:root:
# Source:il souffre d un mal de dents . <EOS> <PAD>
# Target:he is suffering from toothache . <EOS> <PAD> <PAD> <PAD>
# Decode:he is suffering from toothache .
# INFO:root:
# Source:je ne me sens pas bien . <EOS> <PAD> <PAD>
# Target:i m not feeling well . <EOS> <PAD> <PAD> <PAD>
# Decode:i m not feeling well .
# INFO:root:
# Source:je suis pret pour le combat . <EOS> <PAD> <PAD>
# Target:i m ready for the fight . <EOS> <PAD> <PAD>
# Decode:i m ready for the fight .
# INFO:root:
# Source:il est casse couilles avec moi . <EOS> <PAD> <PAD>
# Target:he is giving me a hard time . <EOS> <PAD>
# Decode:he s putting his husband .
# INFO:root:
# Source:nous nous dirigeons a l est . <EOS> <PAD> <PAD>
# Target:we re going east . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:we re going east .
# INFO:root:
# Source:j en ai marre du poisson ! <EOS> <PAD> <PAD>
# Target:i m sick of fish . <EOS> <PAD> <PAD> <PAD>
# Decode:i m sick of fish .
# INFO:root:
# Source:il est la pour quelques jours . <EOS> <PAD> <PAD>
# Target:he is there for a few days . <EOS> <PAD>
# Decode:he is on the part of a long days .
# INFO:root:
# Source:vous etes trop dur avec vous . <EOS> <PAD> <PAD>
# Target:you re too hard on yourself . <EOS> <PAD> <PAD>
# Decode:you re too hard on yourself .
# INFO:root:
# Source:il se promene en sous vetements . <EOS> <PAD> <PAD>
# Target:he s walking around in his underwear . <EOS> <PAD>
# Decode:he s walking around in his underwear .
# INFO:root:
# Source:nous sommes en train de gagner . <EOS> <PAD> <PAD>
# Target:we re winning . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re losing it .
# INFO:root:
# Source:il commence a avoir les jetons . <EOS> <PAD> <PAD>
# Target:he s getting cold feet . <EOS> <PAD> <PAD> <PAD>
# Decode:he s getting cold feet .
# INFO:root:
# Source:tu n es pas si interessant . <EOS> <PAD> <PAD>
# Target:you re not that interesting . <EOS> <PAD> <PAD> <PAD>
# Decode:you re not that interesting .
# INFO:root:
# Source:vous etes gares en double file . <EOS> <PAD> <PAD>
# Target:you re double parked . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re double parked .
# INFO:root:
# Source:vous n etes pas assez rapide . <EOS> <PAD> <PAD>
# Target:you re not fast enough . <EOS> <PAD> <PAD> <PAD>
# Decode:you re not fast enough .
# INFO:root:
# Source:je suis plus petit que vous . <EOS> <PAD> <PAD>
# Target:i m shorter than you . <EOS> <PAD> <PAD> <PAD>
# Decode:i m shorter than you .
# INFO:root:
# Source:je peux nager dans la riviere . <EOS> <PAD> <PAD>
# Target:i am allowed to swim in the river . <EOS>
# Decode:i am allowed to swim in the river .
# INFO:root:
# Source:nous sommes presque comme des freres . <EOS> <PAD> <PAD>
# Target:we re almost like brothers . <EOS> <PAD> <PAD> <PAD>
# Decode:we re almost like brothers .
# INFO:root:
# Source:il oublie toujours des choses . <EOS> <PAD> <PAD> <PAD>
# Target:he is always forgetting things . <EOS> <PAD> <PAD> <PAD>
# Decode:he is always forgetting things .
# INFO:root:
# Source:je suis un peu rouille . <EOS> <PAD> <PAD> <PAD>
# Target:i m a little rusty . <EOS> <PAD> <PAD> <PAD>
# Decode:i m a little disappointed .
# INFO:root:
# Source:elle saute a la corde . <EOS> <PAD> <PAD> <PAD>
# Target:she is skipping rope . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:she s skipping rope .
# INFO:root:
# Source:il est bon en gymnastique . <EOS> <PAD> <PAD> <PAD>
# Target:he is good at gymnastics . <EOS> <PAD> <PAD> <PAD>
# Decode:he is good at driving .
# INFO:root:
# Source:c est un avocat competent . <EOS> <PAD> <PAD> <PAD>
# Target:he is a capable lawyer . <EOS> <PAD> <PAD> <PAD>
# Decode:he s a southpaw .
# INFO:root:
# Source:tu es une veritable amie . <EOS> <PAD> <PAD> <PAD>
# Target:you re a true friend . <EOS> <PAD> <PAD> <PAD>
# Decode:you re a true friend .
# INFO:root:
# Source:je suis juste curieux . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m just curious . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m just curious .
# INFO:root:
# Source:vous etes en retard . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very late . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you are late .
# INFO:root:
# Source:tu es incroyablement naif . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you are incredibly naive . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you are unbelievably naive .
# INFO:root:
# Source:tu es tres emotive . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very emotional . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very emotional .
# INFO:root:
# Source:tu es la professeur . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re the teacher . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re the teacher .
# INFO:root:
# Source:il est toujours celibataire . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:he s still single . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he s still single .
# INFO:root:
# Source:tu es tres contrarie . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:you re very upset . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:you re very upset .
# INFO:root:
# Source:j en suis consciente . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m aware of that . <EOS> <PAD> <PAD> <PAD>
# Decode:i m aware of that .
# INFO:root:
# Source:j en suis contente . <EOS> <PAD> <PAD> <PAD> <PAD>
# Target:i m happy with that . <EOS> <PAD> <PAD> <PAD>
# Decode:i m happy with it .
# INFO:root:
# Source:tu es adorable . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re adorable . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re adorable .
# INFO:root:
# Source:je suis fiable . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i m reliable . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:i m reliable .
# INFO:root:
# Source:vous etes creatif . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re creative . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re creative .
# INFO:root:
# Source:je suis perfectionniste . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:i m a perfectionist . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:i m a perfectionist .
# INFO:root:
# Source:tu es difficile . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re fussy . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re fussy .
# INFO:root:
# Source:tu es endurante . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:you re resilient . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:you re resilient .
# INFO:root:
# Source:il est detective . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:he is a detective . <EOS> <PAD> <PAD> <PAD> <PAD>
# Decode:he s an aristocrat .
# INFO:root:
# Source:nous sommes remuees . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Target:we re shaken . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Decode:we re shaken .
# INFO:root:LOSS: 0.20969200134277344
# 201it [00:40,  2.27it/s]
# torch.Size([50, 1, 10])
# INFO:root:LOSS: 0.23165535926818848
# 202it [00:40,  2.53it/s]INFO:root:LOSS: 0.23402714729309082
# 203it [00:41,  2.97it/s]INFO:root:LOSS: 0.2915608584880829
# 204it [00:41,  3.31it/s]INFO:root:LOSS: 0.21157075464725494
# 205it [00:41,  3.57it/s]INFO:root:LOSS: 0.2496310919523239
# 206it [00:41,  3.73it/s]INFO:root:LOSS: 0.25414136052131653
# 207it [00:42,  3.96it/s]INFO:root:LOSS: 0.2163846641778946
# 208it [00:42,  4.00it/s]INFO:root:LOSS: 0.24866628646850586
# 209it [00:42,  4.18it/s]INFO:root:LOSS: 0.2152981162071228
# 210it [00:42,  4.16it/s]INFO:root:LOSS: 0.2334481030702591
# 211it [00:42,  4.21it/s]INFO:root:LOSS: 0.23430709540843964
# 212it [00:43,  4.53it/s]INFO:root:LOSS: 0.21807213127613068
# 213it [00:43,  4.85it/s]INFO:root:LOSS: 0.22907280921936035
# 214it [00:43,  5.12it/s]INFO:root:LOSS: 0.2530422508716583
# 215it [00:43,  5.32it/s]INFO:root:LOSS: 0.30423039197921753
# 216it [00:43,  5.42it/s]INFO:root:LOSS: 0.224481999874115
# 217it [00:43,  4.93it/s]

# %%
#reference : https://github.com/rawmarshmellows/pytorch-batch-luong-attention/blob/master/train_luong_attention.py

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2f71726bed4c> in <module>
# ----> 1 sqrt(3)
#
# NameError: name 'sqrt' is not defined
